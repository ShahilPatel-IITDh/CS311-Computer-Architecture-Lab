# %%
import pandas as pd
import matplotlib.pyplot as plt

# our data
# data = [["Australia", 2500, 2021],["Bangladesh", 1000, 2021],["England", 2000, 2021],["India", 3000, 2021],["Srilanka", 1500, 2021]]

# %%
data_q1 =[["16B",0.025002256,0.02238806, 0.022807017, 0.030265596, 0.03243848],
        ["128B",0.11878216,0.021978023,0.053682037, 0.07174231, 0.045383412],
        ["512B",0.10448887,0.021582734,0.04797048,0.063885264,0.04347826],
        ["1024B",0.09750088,0.021201413,0.046044864,0.0601227,0.04172662]
        ]
for cnt in data_q1:
    for i in range(5):
        cnt[i+1] = cnt[i+1]*1000
# dataframe
dataFrame = pd.DataFrame(data_q1, columns=["Sizes","Descending","EvenOdd","Fibonacci","Palindrome","Prime"])


# plotting the dataframe
dataFrame.plot(x="Sizes", y=["Descending","EvenOdd","Fibonacci","Palindrome","Prime"], kind="line",ylabel='IPC (10^-3)', figsize=(10, 9))

# displaying line graph
plt.show()

# %%
data_q1 =[["16B",0.09750088,0.021201413,0.046044864,0.0601227,0.04172662],
        ["128B",0.10386202,0.021352313,0.047852762,0.060270604,0.041847043],
        ["512B",0.100580975,0.021276595,0.04693141,0.06019656,0.041786745],
        ["1024B",0.09750088,0.021201413,0.046044864,0.0601227,0.04172662]
        ]
        
for cnt in data_q1:
    for i in range(5):
        cnt[i+1] = cnt[i+1]*1000

# dataframe
dataFrame = pd.DataFrame(data_q1, columns=["Sizes","Descending","EvenOdd","Fibonacci","Palindrome","Prime"])


# plotting the dataframe
dataFrame.plot(x="Sizes", y=["Descending","EvenOdd","Fibonacci","Palindrome","Prime"], kind="line",ylabel='IPC (10^-3)', figsize=(10, 9))

# displaying line graph
plt.show()

# %%
data_q1 =[["16B",0.022680413],
        ["128B",0.022312373]
        ]
        
for cnt in data_q1:
    for i in range(1):
        cnt[i+1] = cnt[i+1]*1000

# Dataframe
dataFrame = pd.DataFrame(data_q1, columns=["Sizes","Greatest"])

# Plotting the dataframe
dataFrame.plot(x="Sizes", y=["Greatest"], kind="line", ylabel='IPC (10^-3)', figsize=(10, 9))

# Displaying line graph
plt.show()

# %%
data_q1 =[["16B",0.022],
        ["128B",0.021868788]
        ]
        
for cnt in data_q1:
    for i in range(1):
        cnt[i+1] = cnt[i+1]*1000

# Dataframe
dataFrame = pd.DataFrame(data_q1, columns=["Sizes","Greatest"])

# Plotting the dataframe
dataFrame.plot(x="Sizes", y=["Greatest"], kind="line", ylabel='IPC (10^-3)', figsize=(10, 9))

# Displaying line graph
plt.show()
